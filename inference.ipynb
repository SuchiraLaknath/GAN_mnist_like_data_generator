# %%
import torch
from models.Generator_Model import Generator
from training_utils import training_config
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image
import cv2

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
gen = Generator(training_config.z_dim).to(device)
gen.load_state_dict(torch.load("models\saved_models\generator\_gen_epoch_49_model"))
# Out:
# <All keys matched successfully>

# %%
fake_noise = torch.randn(1,training_config.z_dim, device=device)
fake = gen(fake_noise)

# %%
image_tensor = (fake + 1) / 2
image_unflat = image_tensor.detach().cpu().squeeze().numpy()

# %%
plt.imshow(image_unflat,cmap='Greys', interpolation='nearest')
plt.show()
